# %%
# Import necessary
import pandas as pd
from pathlib import Path

# %%
# Set Path to data
housing_path = Path('Raw_Data/Housing_Data.csv')
rent_path = Path('Raw_Data/Fair_Market_Rent_Data.csv')

# %%
# Read in CSV files
housing_data = pd.read_csv(housing_path)
rent_data = pd.read_csv(rent_path)

# %%
# Check housing_data
housing_data.head()
# Out:
#   State       County Name                Metropolitan/FMR Area Name  \
# 0    AL  Jefferson County  Birmingham-Hoover, AL HUD Metro FMR Area
# 1    AL  St. Clair County  Birmingham-Hoover, AL HUD Metro FMR Area
# 2    AL     Shelby County  Birmingham-Hoover, AL HUD Metro FMR Area
# 3    AL    Chilton County     Chilton County, AL HUD Metro FMR Area
# 4    AL     Walker County      Walker County, AL HUD Metro FMR Area
#
#       1-Unit     2-unit     3-unit     4-unit Unadjusted Median Value  \
# 0  $199,000   $254,000   $308,000   $381,000                $209,000
# 1  $195,000   $250,000   $302,000   $375,000                $205,400
# 2  $202,000   $258,000   $313,000   $388,000                $212,550
# 3  $150,000   $193,000   $233,000   $289,000                $158,350
# 4  $150,000   $193,000   $233,000   $289,000                $158,350
#
#    Years Worth of Sales Data* Number of Sales for Unadjusted Median**  ...  \
# ...

# %%
# Rename columns names for rent_data
rent_columns = ['id', 'studio rent', '1 bdrm rent', '2 bdrm rent', '3 bdrm rent', '4 bdrm rent', 'state id', 'metro id', 'area name', 'county code', 'cousub', 'county name', 'county town name', 'population', 'state', 'metro']
rent_data.columns = rent_columns
rent_data.head()
# Out:
#           id  studio rent  1 bdrm rent  2 bdrm rent  3 bdrm rent  4 bdrm rent  \
# 0  100199999          640          766          908         1148         1520
# 1  100399999          718          723          922         1249         1584
# 2  100599999          488          492          648          806          907
# 3  100799999          817          871         1002         1303         1409
# 4  100999999          817          871         1002         1303         1409
#
#    state id          metro id                                 area name  \
# 0         1  METRO33860M33860                        Montgomery, AL MSA
# 1         1  METRO19300M19300             Daphne-Fairhope-Foley, AL MSA
# 2         1  NCNTY01005N01005                        Barbour County, AL
# 3         1  METRO13820M13820  Birmingham-Hoover, AL HUD Metro FMR Area
# 4         1  METRO13820M13820  Birmingham-Hoover, AL HUD Metro FMR Area
#
# ...

# %%
# Drop unneccessary columns from housing_data
housing_data = housing_data.drop(columns=['Unadjusted Median Value', 'Years Worth of Sales Data*', 'Number of Sales for Unadjusted Median**', 'Years Worth of Sales Data*.1', 'Number of Sales for Unadjusted Median**.1', 'Geographic Area Used.1', 'Metropolitan/FMR Area Name.1'])
housing_data.head()
# Out:
#   State       County Name                Metropolitan/FMR Area Name  \
# 0    AL  Jefferson County  Birmingham-Hoover, AL HUD Metro FMR Area
# 1    AL  St. Clair County  Birmingham-Hoover, AL HUD Metro FMR Area
# 2    AL     Shelby County  Birmingham-Hoover, AL HUD Metro FMR Area
# 3    AL    Chilton County     Chilton County, AL HUD Metro FMR Area
# 4    AL     Walker County      Walker County, AL HUD Metro FMR Area
#
#       1-Unit     2-unit     3-unit     4-unit Geographic Area Used   1-Unit.1  \
# 0  $199,000   $254,000   $308,000   $381,000                County  $243,000
# 1  $195,000   $250,000   $302,000   $375,000                County  $243,000
# 2  $202,000   $258,000   $313,000   $388,000                County  $243,000
# 3  $150,000   $193,000   $233,000   $289,000       Non-Metro State  $243,000
# 4  $150,000   $193,000   $233,000   $289,000       Non-Metro State  $243,000
#
#     2-unit.1   3-unit.1   4-unit.1 Unadjusted Median Value.1  \
# ...

# %%
# Drop unneccessary columns from housing_data
housing_data = housing_data.drop(columns=['Geographic Area Used', 'Unadjusted Median Value.1', 'state2', 'fipscounty', 'metro_code'])
housing_data.head()
# Out:
#   State       County Name                Metropolitan/FMR Area Name  \
# 0    AL  Jefferson County  Birmingham-Hoover, AL HUD Metro FMR Area
# 1    AL  St. Clair County  Birmingham-Hoover, AL HUD Metro FMR Area
# 2    AL     Shelby County  Birmingham-Hoover, AL HUD Metro FMR Area
# 3    AL    Chilton County     Chilton County, AL HUD Metro FMR Area
# 4    AL     Walker County      Walker County, AL HUD Metro FMR Area
#
#       1-Unit     2-unit     3-unit     4-unit   1-Unit.1   2-unit.1  \
# 0  $199,000   $254,000   $308,000   $381,000   $243,000   $311,000
# 1  $195,000   $250,000   $302,000   $375,000   $243,000   $311,000
# 2  $202,000   $258,000   $313,000   $388,000   $243,000   $311,000
# 3  $150,000   $193,000   $233,000   $289,000   $243,000   $311,000
# 4  $150,000   $193,000   $233,000   $289,000   $243,000   $311,000
#
#     3-unit.1   4-unit.1       Unnamed: 20
# 0  $377,000   $467,000   METRO13820M13820
# 1  $377,000   $467,000   METRO13820M13820
# ...

# %%
# Rename Unnamed:20 column
housing_data = housing_data.rename(columns={'Unnamed: 20': 'metro id'})
housing_data.head()
# Out:
#   State       County Name                Metropolitan/FMR Area Name  \
# 0    AL  Jefferson County  Birmingham-Hoover, AL HUD Metro FMR Area
# 1    AL  St. Clair County  Birmingham-Hoover, AL HUD Metro FMR Area
# 2    AL     Shelby County  Birmingham-Hoover, AL HUD Metro FMR Area
# 3    AL    Chilton County     Chilton County, AL HUD Metro FMR Area
# 4    AL     Walker County      Walker County, AL HUD Metro FMR Area
#
#       1-Unit     2-unit     3-unit     4-unit   1-Unit.1   2-unit.1  \
# 0  $199,000   $254,000   $308,000   $381,000   $243,000   $311,000
# 1  $195,000   $250,000   $302,000   $375,000   $243,000   $311,000
# 2  $202,000   $258,000   $313,000   $388,000   $243,000   $311,000
# 3  $150,000   $193,000   $233,000   $289,000   $243,000   $311,000
# 4  $150,000   $193,000   $233,000   $289,000   $243,000   $311,000
#
#     3-unit.1   4-unit.1          metro id
# 0  $377,000   $467,000   METRO13820M13820
# 1  $377,000   $467,000   METRO13820M13820
# ...

# %%
# Drop unneccessary columns for rent_data
rent_data = rent_data.drop(columns=['id', 'state id', 'county code', 'cousub', 'county town name', 'population', 'metro'])
rent_data.head()
# Out:
#    studio rent  1 bdrm rent  2 bdrm rent  3 bdrm rent  4 bdrm rent  \
# 0          640          766          908         1148         1520
# 1          718          723          922         1249         1584
# 2          488          492          648          806          907
# 3          817          871         1002         1303         1409
# 4          817          871         1002         1303         1409
#
#            metro id                                 area name     county name  \
# 0  METRO33860M33860                        Montgomery, AL MSA  Autauga County
# 1  METRO19300M19300             Daphne-Fairhope-Foley, AL MSA  Baldwin County
# 2  NCNTY01005N01005                        Barbour County, AL  Barbour County
# 3  METRO13820M13820  Birmingham-Hoover, AL HUD Metro FMR Area     Bibb County
# 4  METRO13820M13820  Birmingham-Hoover, AL HUD Metro FMR Area   Blount County
#
#   state
# 0    AL
# 1    AL
# 2    AL
# 3    AL
# 4    AL

# %%
# Check for null values in rent_data
rent_data.isnull().sum()
# Out:
# studio rent    0
# 1 bdrm rent    0
# 2 bdrm rent    0
# 3 bdrm rent    0
# 4 bdrm rent    0
# metro id       0
# area name      0
# county name    0
# state          0
# dtype: int64

# %%
# Check for null values in housing_data
housing_data.isnull().sum()
# Out:
# State                         0
# County Name                   0
# Metropolitan/FMR Area Name    0
# 1-Unit                        0
# 2-unit                        0
# 3-unit                        0
# 4-unit                        0
# 1-Unit.1                      0
# 2-unit.1                      0
# 3-unit.1                      0
# 4-unit.1                      0
# metro id                      0
# dtype: int64

# %%
# Set metro code as index for both tables
housing_data = housing_data.set_index('metro id')
rent_data = rent_data.set_index('metro id')

# %%
# Join housing_data and rent_data tables
housing_cost_df = pd.merge(housing_data, rent_data, on='metro id', how='inner')
housing_cost_df.head()
# Out:
#                  State       County Name  \
# metro id
# METRO13820M13820    AL  Jefferson County
# METRO13820M13820    AL  Jefferson County
# METRO13820M13820    AL  Jefferson County
# METRO13820M13820    AL  Jefferson County
# METRO13820M13820    AL  Jefferson County
#
#                                 Metropolitan/FMR Area Name     1-Unit  \
# metro id
# METRO13820M13820  Birmingham-Hoover, AL HUD Metro FMR Area  $199,000
# METRO13820M13820  Birmingham-Hoover, AL HUD Metro FMR Area  $199,000
# METRO13820M13820  Birmingham-Hoover, AL HUD Metro FMR Area  $199,000
# METRO13820M13820  Birmingham-Hoover, AL HUD Metro FMR Area  $199,000
# METRO13820M13820  Birmingham-Hoover, AL HUD Metro FMR Area  $199,000
#
#                      2-unit     3-unit     4-unit   1-Unit.1   2-unit.1  \
# metro id
# METRO13820M13820  $254,000   $308,000   $381,000   $243,000   $311,000
# METRO13820M13820  $254,000   $308,000   $381,000   $243,000   $311,000
# ...

# %%
# Drop repeat columns
housing_cost_df = housing_cost_df.drop(columns=['area name', 'county name', 'state'])
housing_cost_df.tail()
# Out:
#                  State        County Name     Metropolitan/FMR Area Name  \
# metro id
# NCNTY72923N72923    PR  Vieques Municipio  Puerto Rico HUD Nonmetro Area
# NCNTY72923N72923    PR  Vieques Municipio  Puerto Rico HUD Nonmetro Area
# NCNTY78010N78010    VI          St. Croix           St. Croix Island, VI
# NCNTY78020N78020    VI           St. John            St. John Island, VI
# NCNTY78030N78030    VI         St. Thomas          St. Thomas Island, VI
#
#                      1-Unit     2-unit     3-unit     4-unit   1-Unit.1  \
# metro id
# NCNTY72923N72923  $121,000   $155,000   $188,000   $233,000   $243,000
# NCNTY72923N72923  $121,000   $155,000   $188,000   $233,000   $243,000
# NCNTY78010N78010  $219,000   $280,000   $339,000   $420,000   $243,000
# NCNTY78020N78020  $444,000   $569,000   $689,000   $853,000   $444,000
# NCNTY78030N78030  $332,000   $425,000   $515,000   $638,000   $332,000
#
# ...

# %%
# Create a list of the city names to search for in the Metropolitan/FMR Area Name column of the housing_cost_df
search_for = ['New York',
              'Los Angeles',
              'Chicago',
              'Houston',
              'Phoenix',
              'Philadelphia',
              'San Antonio',
              'San Diego',
              'Dallas',
              'San Jose',
              'Austin',
              'Jacksonville',
              'Fort Worth',
              'Columbus',
              'Indianapolis',
              'Charlotte',
              'San Francisco',
              'Seattle',
              'Denver',
              'DC',
              'Nashville',
              'Oklahoma City',
              'El Paso',
              'Boston',
              'Portland'
]

# Search for names of cities in housing_cost_df 
filtered_housing_df = housing_cost_df[(housing_cost_df['Metropolitan/FMR Area Name'].str.contains('|'.join(search_for)))]

# Check new DataFrame
filtered_housing_df
# Out:
#                  State       County Name  \
# metro id
# METRO17980M17980    AL    Russell County
# METRO17980M17980    AL    Russell County
# METRO17980M17980    AL    Russell County
# METRO17980M17980    AL    Russell County
# METRO17980M17980    AL    Russell County
# ...                ...               ...
# NCNTY51037N51037    VA  Charlotte County
# METRO42660MM7600    WA       King County
# METRO42660MM7600    WA       King County
# METRO42660MM7600    WA  Snohomish County
# METRO42660MM7600    WA  Snohomish County
#
#                                Metropolitan/FMR Area Name     1-Unit  \
# metro id
# METRO17980M17980                      Columbus, GA-AL MSA  $150,000
# METRO17980M17980                      Columbus, GA-AL MSA  $150,000
# METRO17980M17980                      Columbus, GA-AL MSA  $150,000
# METRO17980M17980                      Columbus, GA-AL MSA  $150,000
# METRO17980M17980                      Columbus, GA-AL MSA  $150,000
# ...

# %%
# Check for duplicate rows
filtered_housing_df.duplicated()
# Out:
# metro id
# METRO17980M17980    False
# METRO17980M17980     True
# METRO17980M17980     True
# METRO17980M17980     True
# METRO17980M17980     True
#                     ...
# NCNTY51037N51037    False
# METRO42660MM7600    False
# METRO42660MM7600     True
# METRO42660MM7600    False
# METRO42660MM7600     True
# Length: 2019, dtype: bool

# %%
city_housing_df = filtered_housing_df.drop_duplicates().copy()
city_housing_df
# Out:
#                  State           County Name  \
# metro id
# METRO17980M17980    AL        Russell County
# METRO17980M17980    GA  Chattahoochee County
# METRO17980M17980    GA         Harris County
# METRO17980M17980    GA         Marion County
# METRO17980M17980    GA       Muscogee County
# ...                ...                   ...
# METRO16820M16820    VA         Nelson County
# METRO16820M16820    VA  Charlottesville city
# NCNTY51037N51037    VA      Charlotte County
# METRO42660MM7600    WA           King County
# METRO42660MM7600    WA      Snohomish County
#
#                                Metropolitan/FMR Area Name     1-Unit  \
# metro id
# METRO17980M17980                      Columbus, GA-AL MSA  $150,000
# METRO17980M17980                      Columbus, GA-AL MSA  $170,000
# METRO17980M17980                      Columbus, GA-AL MSA  $222,000
# METRO17980M17980                      Columbus, GA-AL MSA  $170,000
# ...

# %%
# Create list for state abbreviations for 25 most populous cities
st_search_for = ['NY',
                 'CA',
                 'TX',
                 'AZ',
                 'PA',
                 'FL',
                 'OH',
                 'IN',
                 'IL',
                 'NC',
                 'WA',
                 'CO',
                 'TN',
                 'OK',
                 'MA',
                 'DC',
                 'OR',
]

# Filter data for states that contain the appropriate cities (This is because some city names are located in multiple states)
clean_housing_df = city_housing_df[(city_housing_df['State'].str.contains('|'.join(st_search_for)))]
clean_housing_df.sort_values('State').head(25)
# Out:
#                  State           County Name  \
# metro id
# METRO38060M38060    AZ       Maricopa County
# METRO38060M38060    AZ          Pinal County
# METRO31080MM4480    CA    Los Angeles County
# METRO41740M41740    CA      San Diego County
# METRO41860MM7360    CA          Marin County
# METRO41860MM7360    CA  San Francisco County
# METRO41860MM7360    CA      San Mateo County
# METRO41940M41940    CA    Santa Clara County
# METRO19740M19740    CO           Park County
# METRO19740M19740    CO      Jefferson County
# METRO19740M19740    CO         Gilpin County
# METRO19740M19740    CO         Elbert County
# METRO19740M19740    CO        Douglas County
# METRO19740M19740    CO     Broomfield County
# METRO19740M19740    CO    Clear Creek County
# METRO19740M19740    CO       Arapahoe County
# METRO19740M19740    CO          Adams County
# METRO19740M19740    CO         Denver County
# METRO47900M47900    DC  District of Columbia
# ...

# %%
# For simplicity, drop 1-Unit.1, 2-unit.1, 3-unit.1 4-unit.1
clean_housing_df = clean_housing_df.drop(columns=['1-Unit.1', '2-unit.1', '3-unit.1', '4-unit.1'])
clean_housing_df
# Out:
#                  State         County Name  \
# metro id
# METRO38060M38060    AZ     Maricopa County
# METRO38060M38060    AZ        Pinal County
# METRO31080MM4480    CA  Los Angeles County
# METRO41740M41740    CA    San Diego County
# METRO41860MM7360    CA        Marin County
# ...                ...                 ...
# METRO41700M41700    TX    Guadalupe County
# METRO41700M41700    TX       Wilson County
# NCNTY48225N48225    TX      Houston County
# METRO42660MM7600    WA         King County
# METRO42660MM7600    WA    Snohomish County
#
#                                          Metropolitan/FMR Area Name  \
# metro id
# METRO38060M38060                    Phoenix-Mesa-Scottsdale, AZ MSA
# METRO38060M38060                    Phoenix-Mesa-Scottsdale, AZ MSA
# METRO31080MM4480  Los Angeles-Long Beach-Glendale, CA HUD Metro ...
# METRO41740M41740                         San Diego-Carlsbad, CA MSA
# METRO41860MM7360               San Francisco, CA HUD Metro FMR Area
# ...

# %%
# There are still rows not pertaining to appropriate cities due to naming similarities. Dataset is much smaller and can filter out unneccessary cities by name
clean_housing_data = clean_housing_df.reset_index()
clean_housing_data = clean_housing_data.set_index('Metropolitan/FMR Area Name')
clean_housing_data = clean_housing_data.drop(['Columbus, IN MSA', 
                                              'Jacksonville, NC MSA', 
                                              'Columbus County, NC', 
                                              'Houston County, TN', 
                                              'Austin County, TX HUD Metro FMR Area', 
                                              'Houston County, TX'])
clean_housing_data = clean_housing_data.reset_index()
clean_housing_data
# Out:
#                             Metropolitan/FMR Area Name          metro id  \
# 0                      Phoenix-Mesa-Scottsdale, AZ MSA  METRO38060M38060
# 1                      Phoenix-Mesa-Scottsdale, AZ MSA  METRO38060M38060
# 2    Los Angeles-Long Beach-Glendale, CA HUD Metro ...  METRO31080MM4480
# 3                           San Diego-Carlsbad, CA MSA  METRO41740M41740
# 4                 San Francisco, CA HUD Metro FMR Area  METRO41860MM7360
# ..                                                 ...               ...
# 113   San Antonio-New Braunfels, TX HUD Metro FMR Area  METRO41700M41700
# 114   San Antonio-New Braunfels, TX HUD Metro FMR Area  METRO41700M41700
# 115   San Antonio-New Braunfels, TX HUD Metro FMR Area  METRO41700M41700
# 116            Seattle-Bellevue, WA HUD Metro FMR Area  METRO42660MM7600
# 117            Seattle-Bellevue, WA HUD Metro FMR Area  METRO42660MM7600
#
#     State         County Name     1-Unit     2-unit       3-unit       4-unit  \
# ...

# %%
# Drop metro id column
clean_housing_data = clean_housing_data.drop(columns='metro id')
clean_housing_data.head()
# Out:
#                           Metropolitan/FMR Area Name State  \
# 0                    Phoenix-Mesa-Scottsdale, AZ MSA    AZ
# 1                    Phoenix-Mesa-Scottsdale, AZ MSA    AZ
# 2  Los Angeles-Long Beach-Glendale, CA HUD Metro ...    CA
# 3                         San Diego-Carlsbad, CA MSA    CA
# 4               San Francisco, CA HUD Metro FMR Area    CA
#
#           County Name     1-Unit     2-unit       3-unit       4-unit  \
# 0     Maricopa County  $258,000   $330,000     $400,000     $495,000
# 1        Pinal County  $252,000   $322,000     $390,000     $483,000
# 2  Los Angeles County  $510,000   $652,000     $790,000     $979,000
# 3    San Diego County  $518,000   $663,000     $803,000     $994,000
# 4        Marin County  $664,000   $850,000   $1,029,000   $1,275,000
#
#    studio rent  1 bdrm rent  2 bdrm rent  3 bdrm rent  4 bdrm rent
# 0          933         1032         1251         1765         2010
# ...

# %%
# Save table as CSV file in Clean_Data folder
clean_housing_data.to_csv('Clean_Data/clean_housing_data.csv', index=False)

# %%
# Remove $ from housing prices
# 1 Unit
clean_housing_data['1-Unit'] = clean_housing_data['1-Unit'].str.replace('$', '')
clean_housing_data['1-Unit'] = clean_housing_data['1-Unit'].str.replace(',', '')
clean_housing_data['1-Unit'] = clean_housing_data['1-Unit'].astype('float')

# 2 Unit
clean_housing_data['2-unit'] = clean_housing_data['2-unit'].str.replace('$', '')
clean_housing_data['2-unit'] = clean_housing_data['2-unit'].str.replace(',', '')
clean_housing_data['2-unit'] = clean_housing_data['2-unit'].astype('float')

# 3 Unit
clean_housing_data['3-unit'] = clean_housing_data['3-unit'].str.replace('$', '')
clean_housing_data['3-unit'] = clean_housing_data['3-unit'].str.replace(',', '')
clean_housing_data['3-unit'] = clean_housing_data['3-unit'].astype('float')

# 4 Unit
clean_housing_data['4-unit'] = clean_housing_data['4-unit'].str.replace('$', '')
clean_housing_data['4-unit'] = clean_housing_data['4-unit'].str.replace(',', '')
clean_housing_data['4-unit'] = clean_housing_data['4-unit'].astype('float')
# Out:
# /Users/jacobeckhardt/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/jacobeckhardt/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#
# ...

# %%
# Group housing data by cities
clean_housing_data_grp = clean_housing_data.groupby('Metropolitan/FMR Area Name').mean().round(2)
clean_housing_data_grp
# Out:
#                                                        1-Unit     2-unit  \
# Metropolitan/FMR Area Name
# Austin-Round Rock, TX MSA                           276400.00  353400.00
# Boston-Cambridge-Quincy, MA-NH HUD Metro FMR Area   456400.00  583800.00
# Charlotte-Concord-Gastonia, NC-SC HUD Metro FMR...  234750.00  300000.00
# Chicago-Joliet-Naperville, IL HUD Metro FMR Area    249166.67  318666.67
# Columbus, OH HUD Metro FMR Area                     209714.29  268285.71
# Dallas, TX HUD Metro FMR Area                       254857.14  326285.71
# Denver-Aurora-Lakewood, CO MSA                      399000.00  510800.00
# El Paso, TX HUD Metro FMR Area                      162000.00  207000.00
# Fort Worth-Arlington, TX HUD Metro FMR Area         233666.67  299000.00
# Houston-The Woodlands-Sugar Land, TX HUD Metro ...  217857.14  278571.43
# Indianapolis-Carmel, IN HUD Metro FMR Area          192111.11  245555.56
# ...

# %%
# Rename Metropolitan/FMR Area Name to the primary city
housing_data_grp = clean_housing_data_grp.reset_index()
housing_data_grp['Metropolitan/FMR Area Name'].replace({'Austin-Round Rock, TX MSA': 'Austin, TX',
                                                        'Boston-Cambridge-Quincy, MA-NH HUD Metro FMR Area': 'Boston, MA',
                                                        'Charlotte-Concord-Gastonia, NC-SC HUD Metro FMR Area': 'Charlotte, NC',
                                                        'Chicago-Joliet-Naperville, IL HUD Metro FMR Area': 'Chicago, IL',
                                                        'Columbus, OH HUD Metro FMR Area': 'Columbus, OH',
                                                        'Dallas, TX HUD Metro FMR Area': 'Dallas, TX',
                                                        'Denver-Aurora-Lakewood, CO MSA': 'Denver, CO',
                                                        'El Paso, TX HUD Metro FMR Area': 'El Paso, TX',
                                                        'Fort Worth-Arlington, TX HUD Metro FMR Area': 'Fort Worth, TX',
                                                        'Houston-The Woodlands-Sugar Land, TX HUD Metro FMR Area': 'Houston, TX',
                                                        'Indianapolis-Carmel, IN HUD Metro FMR Area': 'Indianapolis, IN',
                                                        'Jacksonville, FL HUD Metro FMR Area': 'Jacksonville, FL',
                                                        'Los Angeles-Long Beach-Glendale, CA HUD Metro FMR Area': 'Los Angeles, CA',
                                                        'Nashville-Davidson--Murfreesboro--Franklin, TN HUD Metro FMR Area': 'Nashville, TN',
                                                        'New York, NY HUD Metro FMR Area': 'New York City, NY',
                                                        'Oklahoma City, OK HUD Metro FMR Area': 'Oklahoma City, OK',
                                                        'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD MSA': 'Philadelphia, PA',
                                                        'Phoenix-Mesa-Scottsdale, AZ MSA': 'Phoenix, AZ',
                                                        'Portland-Vancouver-Hillsboro, OR-WA MSA': 'Portland, OR',
                                                        'San Antonio-New Braunfels, TX HUD Metro FMR Area': 'San Antonio, TX',
                                                        'San Diego-Carlsbad, CA MSA': 'San Diego, CA',
                                                        'San Francisco, CA HUD Metro FMR Area': 'San Francisco, CA',
                                                        'San Jose-Sunnyvale-Santa Clara, CA HUD Metro FMR Area': 'San Jose, CA',
                                                        'Seattle-Bellevue, WA HUD Metro FMR Area': 'Seattle, WA',
                                                        'Washington-Arlington-Alexandria, DC-VA-MD HUD Metro FMR Area': 'Washington D.C.'
                                                       }, inplace=True)
housing_data_grp
# Out:
#    Metropolitan/FMR Area Name     1-Unit     2-unit      3-unit      4-unit  \
# 0                  Austin, TX  276400.00  353400.00   428200.00   531000.00
# 1                  Boston, MA  456400.00  583800.00   707000.00   875600.00
# 2               Charlotte, NC  234750.00  300000.00   363750.00   450500.00
# 3                 Chicago, IL  249166.67  318666.67   386166.67   478333.33
# 4                Columbus, OH  209714.29  268285.71   324571.43   402142.86
# 5                  Dallas, TX  254857.14  326285.71   394857.14   489142.86
# 6                  Denver, CO  399000.00  510800.00   619000.00   766400.00
# 7                 El Paso, TX  162000.00  207000.00   250000.00   310000.00
# 8              Fort Worth, TX  233666.67  299000.00   361666.67   448333.33
# 9                 Houston, TX  217857.14  278571.43   337714.29   418142.86
# 10           Indianapolis, IN  192111.11  245555.56   297333.33   368222.22
# ...

# %%
# Save new file as CSV
housing_data_grp.to_csv('Clean_Data/grouped_housing_data.csv', index=False)
